# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Para ejercitarte y afianzar lo aprendido sobre el análisis bivariante, completa los siguientes ejercicios. Recuerda que necesitarás datos que están en el directorio data que acompaña al notebook (búscalo en el repositorio de ejercicios)
#
# La solución a los mismos se subirá a lo largo del sprint.

# %% [markdown]
# ### Ejercicio 0
#
#
# Importa los paquetes y módulos que necesites a lo largo del notebook

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import bootcampviztools as bcamp

# %% [markdown]
# ### Ejercicio 1

# %% [markdown]
# Carga el dataset de admisiones que conoces de la unidad anterior y que se encuentra en la ruta "./data/admission_data.csv", deshazte de las columnas innecesarias

# %%
df_admisiones= pd.read_csv("./data/admission_data.csv")

# %%
df_admisiones.head()
# Out:
#    Unnamed: 0  Year                    Major Gender Admission
# 0           0  1973       School of Medicine      F  Rejected
# 1           1  1973  Department of Economics      M  Accepted
# 2           2  1973                    Other      F  Accepted
# 3           3  1973                    Other      M  Accepted
# 4           4  1973                    Other      M  Rejected

# %%
df_admisiones=df_admisiones.drop(columns=["Unnamed: 0","Year"])
df_admisiones
# Out:
#                                       Major Gender Admission
# 0                        School of Medicine      F  Rejected
# 1                   Department of Economics      M  Accepted
# 2                                     Other      F  Accepted
# 3                                     Other      M  Accepted
# 4                                     Other      M  Rejected
# ...                                     ...    ...       ...
# 12758                                 Other      M  Accepted
# 12759  Department of Mechanical Engineering      M  Accepted
# 12760                                 Other      F  Rejected
# 12761                                 Other      M  Rejected
# 12762                                 Other      M  Accepted
#
# [12763 rows x 3 columns]

# %% [markdown]
# ### Ejercicio 2

# %% [markdown]
# Haz el análisis bivariante de "Admission" y "Major" (emplea las funciones del workout importándolas del módulo `bootcampviztools`, o utiliza las visualizaciones del notebook en el repositorio) y contesta a las siguientes preguntas:
# * ¿Cuál es el departamento con el mayor porcentaje de admsiones?¿Y el de menor?
# * ¿Existe alguna diferencia destacada entre los departamentos?

# %%
bcamp.plot_categorical_relationship_fin(df_admisiones,"Admission","Major",relative_freq=True,show_values=True)

# %%
bcamp.plot_categorical_relationship_fin(df_admisiones,"Major","Admission",relative_freq=True,show_values=True)

# %% [markdown]
# Mayor porcentaje de Admisiones=Departamento de fisica y astronomia
# Menor porcentaje de Admisiones=Departamento de Psicologia
#
# La mayoria de los departamentos reciben mas rechazos que admisiones
# - solo el de Fisica y Astronomia, y el de Economia tienen un balance positivo
# - Psicologia tienes un pesimo 0.07 de admisiones.
# - El resto se mueven entre un 25% y un 40% de admisión

# %% [markdown]
# ### Ejercicio 3
#
# Repite el análisis para "Admission" y "Gender" y responde a las siguientes preguntas:
# * ¿Existe una diferencia visual significativa entre el porcentaje de admitidos de cada género?
# * ¿Cuál de los dos grupos tiene más admisiones?

# %%
bcamp.plot_categorical_relationship_fin(df_admisiones,"Gender","Admission",relative_freq=True,show_values=True)

# %% [markdown]
# Los solicitantes Masculinos son admitidos un 9% menos que las solicitantes femeninas

# %% [markdown]
# ### Ejercicio 4
#
# Carga el dataset de propinas (tips) que conoces de la unidad anterior y que se encuentra en la ruta "./data/tips.csv", deshazte de las columnas innecesarias

# %%
df_tips= pd.read_csv("./data/tips.csv")

# %%
df_tips=df_tips.drop(columns="Unnamed: 0")

# %%
df_tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Ejercicio 5
#
# Haz el análisis bivariante de "tip" y "sex" (emplea las funciones del workout importándolas del módulo `bootcampviztools`, o utiliza las visualizaciones del notebook en el repositorio), añade el cálculo de la media y mediana de la variable continua por cada valor de la variable categórica, y contesta a las siguientes preguntas:
# * ¿Existe alguna diferencia visualmente significativa entre las propinas de los grupos de la variable "sex"?
# * ¿Son diferentes respecto al  conjunto total?

# %%
df_tips["tip"].mean()
# Out:
# np.float64(2.99827868852459)

# %%
bcamp.plot_categorical_numerical_relationship(df_tips,"sex","tip",measure="mean")

# %%
bcamp.plot_categorical_numerical_relationship(df_tips,"sex","tip",measure="median")

# %% [markdown]
# Los hombres dejan ligeramente mas propina que las mujeres pero no es una diferencia notable, ambos rondan la media global de 2.99

# %% [markdown]
# ### Ejercicio 6
#
# Repite el análisis pero esta vez para "tip" y "smoker", añade también el cálculo de la media y de la mediana de la variable continua por cada valor de la variable categórica, y contesta a las siguiente pregunta:
# * ¿Existe alguna diferencia visualmente significativa entre las propinas de los grupos de la variable "smoker"?

# %%
bcamp.plot_categorical_numerical_relationship(df_tips,"smoker","tip",measure="mean")

# %%
bcamp.plot_categorical_numerical_relationship(df_tips,"smoker","tip",measure="median")

# %% [markdown]
# De media la propina de fumadores y no fumadores es identica.
# En la mediana sin embargo los no fumadores tienen un valor ligeramente menor, lo que puede indicar que existe un grupo relativamente pequeño de no fumadores que deja bastante más propina y que subre la media

# %%
df_tips.loc[df_tips["smoker"]=="Yes",["tip"]].value_counts().hist()
# Out:
# <Axes: >

# %% [markdown]
# ### Ejericicio 7
#
# Carga ahora el datase de accidentes de coches, que se encuentra en la ruta "./data/car_crashes.csv" y deshazte de las columnas innecesarias

# %%
df_accidentes=pd.read_csv("./data/car_crashes.csv",sep="|")

# %%
df_accidentes=df_accidentes.drop(columns="Unnamed: 0")

# %%
df_accidentes.head()
# Out:
#    total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0   18.8     7.332    5.640          18.048       15.040       784.55
# 1   18.1     7.421    4.525          16.290       17.014      1053.48
# 2   18.6     6.510    5.208          15.624       17.856       899.47
# 3   22.4     4.032    5.824          21.056       21.280       827.34
# 4   12.0     4.200    3.360          10.920       10.680       878.41
#
#    ins_losses abbrev
# 0      145.08     AL
# 1      133.93     AK
# 2      110.35     AZ
# 3      142.39     AR
# 4      165.63     CA

# %% [markdown]
# ### Ejercicio 8
#
# Haz un analisis bivairante entre "total" y "speeding". Muestra su diagrama de dispersión y su valor de correlación de pearson obtenido con pandas. Luego contesta a la siguiente pregunta
# * ¿Existe alguna relación visual entre las variables?¿Y numérica?

# %%
df_accidentes[["total","speeding"]].describe()
# Out:
#            total   speeding
# count  51.000000  51.000000
# mean   15.790196   4.998196
# std     4.122002   2.017747
# min     5.900000   1.792000
# 25%    12.750000   3.766500
# 50%    15.600000   4.608000
# 75%    18.500000   6.439000
# max    23.900000   9.450000

# %%
bcamp.grafico_dispersion_con_correlacion(df_accidentes,"total","speeding",20)

# %%
#Visualmente parece que existiera una relación lineal ligera entre ambas

# %%
df_accidentes[["total","speeding"]].corr()
# Out:
#              total  speeding
# total     1.000000  0.611548
# speeding  0.611548  1.000000

# %%
#Numericamente se confirma que la correlación lineal es efectivamente ligera pero notable

# %% [markdown]
# ### Ejercicio 9
#
# Usa scipy tal como lo hicimos en el workout para hacer el test de correlación. ¿Cuál es el p-value?¿Qué podemos decir de la correlación lineal entre "total" y "speeding"?

# %%
import scipy.stats as zipi

# %%
zipi.pearsonr(df_accidentes["total"],df_accidentes["speeding"],alternative='less')
# Out:
# PearsonRResult(statistic=np.float64(0.6115476008001185), pvalue=np.float64(0.9999990664804446))

# %%
# p-value: 0.9999990664804446 indica que existe efectivamente correlación lineal
